# %% [markdown]
# <a href="https://colab.research.google.com/github/mun387344/crop-yield-data-visualization/blob/main/Crop_Yield_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crop Yield Analysis using Matplotlib and Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Region": ["A", "B", "C", "D", "E"],
    "Rainfall": [500, 600, 550, 700, 650],   # mm
    "Temperature": [20, 22, 19, 25, 23],     # °C
    "Yield": [2.5, 3.0, 2.8, 3.5, 3.2]       # tons per hectare
}
df = pd.DataFrame(data)

# %%
plt.plot(df["Yield"])
plt.title("Crop Yield Trend by Region")
plt.xlabel("Region Index")
plt.ylabel("Yield (tons/hectare)")
plt.grid()
plt.show()

# %%
plt.bar(df["Region"], df["Yield"])
plt.title("Crop Yield Comparison by Region")
plt.xlabel("Region")
plt.ylabel("Yield")
plt.show()

# %%
plt.hist(df["Yield"])
plt.title("Yield Distribution")
plt.xlabel("Yield")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["Rainfall"], df["Yield"])
plt.title("Rainfall vs Crop Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield")
plt.show()

# %%
sns.histplot(df["Yield"])
plt.title("Seaborn Yield Distribution")
plt.show()

# %%
sns.boxplot(x=df["Yield"])
plt.title("Yield Box Plot")
plt.show()

# %%
sns.pairplot(df[["Rainfall", "Temperature", "Yield"]])
plt.show()
